# %%
#assignment
import pandas as pd
import numpy as np

# %%
a = pd.read_csv("country_vaccinations.csv")

# %%
a.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
# a = a.dropna()

# %%
a["vaccination_rate"] = a["people_vaccinated"]/200000

# %%
a
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 31235     Zimbabwe      ZWE  2021-07-11           1491397.0
# 31236     Zimbabwe      ZWE  2021-07-12           1531868.0
# 31237     Zimbabwe      ZWE  2021-07-13           1575539.0
# 31238     Zimbabwe      ZWE  2021-07-14           1613640.0
# 31239     Zimbabwe      ZWE  2021-07-15           1666862.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
a["daily_vaccinations_raw"] = a["daily_vaccinations_raw"].fillna(a["daily_vaccinations_raw"].mean())

# %%
a.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN           227366.073989                 NaN
# 1                      NaN           227366.073989              1367.0
# 2                      NaN           227366.073989              1367.0
# 3                      NaN           227366.073989              1367.0
# 4                      NaN           227366.073989              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
a = a.drop("source_name", axis = 1)

# %%
a.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN           227366.073989                 NaN
# 1                      NaN           227366.073989              1367.0
# 2                      NaN           227366.073989              1367.0
# 3                      NaN           227366.073989              1367.0
# 4                      NaN           227366.073989              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
a = a.sort_values(by='total_vaccinations')

# %%
a = a.sort_index(ascending = False)

# %%
a.head()
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 31239  Zimbabwe      ZWE  2021-07-15           1666862.0          1036252.0
# 31238  Zimbabwe      ZWE  2021-07-14           1613640.0           988746.0
# 31237  Zimbabwe      ZWE  2021-07-13           1575539.0           955656.0
# 31236  Zimbabwe      ZWE  2021-07-12           1531868.0           926312.0
# 31235  Zimbabwe      ZWE  2021-07-11           1491397.0           895980.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 31239                 630610.0            53222.000000             33326.0
# 31238                 624894.0            38101.000000             30698.0
# 31237                 619883.0            43671.000000             27567.0
# 31236                 605556.0            40471.000000             23205.0
# 31235                 595417.0           227366.073989             18598.0
#
# ...

# %%
a= a.sort_values(by = ['country','date'])
a.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN           227366.073989                 NaN
# 1                      NaN           227366.073989              1367.0
# 2                      NaN           227366.073989              1367.0
# 3                      NaN           227366.073989              1367.0
# 4                      NaN           227366.073989              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
a["country_code"] = a["iso_code"]

# %%
a.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN           227366.073989                 NaN
# 1                      NaN           227366.073989              1367.0
# 2                      NaN           227366.073989              1367.0
# 3                      NaN           227366.073989              1367.0
# 4                      NaN           227366.073989              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
a = a.drop('country_code', axis = 1)

# %%
a = a.rename(columns = {'iso_code':'country_code'})
a.head()
# Out:
#        country country_code        date  total_vaccinations  \
# 0  Afghanistan          AFG  2021-02-22                 0.0
# 1  Afghanistan          AFG  2021-02-23                 NaN
# 2  Afghanistan          AFG  2021-02-24                 NaN
# 3  Afghanistan          AFG  2021-02-25                 NaN
# 4  Afghanistan          AFG  2021-02-26                 NaN
#
#    people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                0.0                      NaN           227366.073989
# 1                NaN                      NaN           227366.073989
# 2                NaN                      NaN           227366.073989
# 3                NaN                      NaN           227366.073989
# 4                NaN                      NaN           227366.073989
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                             0.0
# 1              1367.0                             NaN
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31240 entries, 0 to 31239
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              31240 non-null  object
#  1   country_code                         31240 non-null  object
#  2   date                                 31240 non-null  object
#  3   total_vaccinations                   17451 non-null  float64
#  4   people_vaccinated                    16554 non-null  float64
#  5   people_fully_vaccinated              13795 non-null  float64
#  6   daily_vaccinations_raw               31240 non-null  float64
#  7   daily_vaccinations                   30948 non-null  float64
#  8   total_vaccinations_per_hundred       17451 non-null  float64
#  9   people_vaccinated_per_hundred        16554 non-null  float64
#  10  people_fully_vaccinated_per_hundred  13795 non-null  float64
# ...

# %%
a = a.set_index(x for x in range(1,31241))

# %%
a
# Out:
#            country country_code        date  total_vaccinations  \
# 1      Afghanistan          AFG  2021-02-22                 0.0
# 2      Afghanistan          AFG  2021-02-23                 NaN
# 3      Afghanistan          AFG  2021-02-24                 NaN
# 4      Afghanistan          AFG  2021-02-25                 NaN
# 5      Afghanistan          AFG  2021-02-26                 NaN
# ...            ...          ...         ...                 ...
# 31236     Zimbabwe          ZWE  2021-07-11           1491397.0
# 31237     Zimbabwe          ZWE  2021-07-12           1531868.0
# 31238     Zimbabwe          ZWE  2021-07-13           1575539.0
# 31239     Zimbabwe          ZWE  2021-07-14           1613640.0
# 31240     Zimbabwe          ZWE  2021-07-15           1666862.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1                    0.0                      NaN           227366.073989
# ...

# %%
#a.isna().sum() is used to find the coloumn with nan values
a.isna().sum()
# Out:
# country                                    0
# country_code                               0
# date                                       0
# total_vaccinations                     13789
# people_vaccinated                      14686
# people_fully_vaccinated                17445
# daily_vaccinations_raw                     0
# daily_vaccinations                       292
# total_vaccinations_per_hundred         13789
# people_vaccinated_per_hundred          14686
# people_fully_vaccinated_per_hundred    17445
# daily_vaccinations_per_million           292
# vaccines                                   0
# source_website                             0
# vaccination_rate                       14686
# dtype: int64

# %%
#df.isna().sum(axis=1)
a.isna().sum(axis=1)
# Out:
# 1        4
# 2        7
# 3        7
# 4        7
# 5        7
#         ..
# 31236    0
# 31237    0
# 31238    0
# 31239    0
# 31240    0
# Length: 31240, dtype: int64

# %%
a["people_fully_vaccinated"] = a["people_fully_vaccinated"].fillna(0)

# %%
a.head()
# Out:
#        country country_code        date  total_vaccinations  \
# 1  Afghanistan          AFG  2021-02-22                 0.0
# 2  Afghanistan          AFG  2021-02-23                 NaN
# 3  Afghanistan          AFG  2021-02-24                 NaN
# 4  Afghanistan          AFG  2021-02-25                 NaN
# 5  Afghanistan          AFG  2021-02-26                 NaN
#
#    people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1                0.0                      0.0           227366.073989
# 2                NaN                      0.0           227366.073989
# 3                NaN                      0.0           227366.073989
# 4                NaN                      0.0           227366.073989
# 5                NaN                      0.0           227366.073989
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 1                 NaN                             0.0
# 2              1367.0                             NaN
# ...

# %%
a["total_vaccinations"] = a["total_vaccinations"].dropna()

# %%
a.head()
# Out:
#        country country_code        date  total_vaccinations  \
# 1  Afghanistan          AFG  2021-02-22                 0.0
# 2  Afghanistan          AFG  2021-02-23                 NaN
# 3  Afghanistan          AFG  2021-02-24                 NaN
# 4  Afghanistan          AFG  2021-02-25                 NaN
# 5  Afghanistan          AFG  2021-02-26                 NaN
#
#    people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1                0.0                      0.0           227366.073989
# 2                NaN                      0.0           227366.073989
# 3                NaN                      0.0           227366.073989
# 4                NaN                      0.0           227366.073989
# 5                NaN                      0.0           227366.073989
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 1                 NaN                             0.0
# 2              1367.0                             NaN
# ...

# %%
a['vaccines'] = a['vaccines'].replace("Moderna, Pfizer/BioNTech", "mRNA vaccines")

# %%
a[a["daily_vaccinations"] < 2]
# Out:
#                     country country_code        date  total_vaccinations  \
# 162                 Albania          ALB  2021-01-28                 NaN
# 163                 Albania          ALB  2021-01-29                 NaN
# 164                 Albania          ALB  2021-01-30                 NaN
# 165                 Albania          ALB  2021-01-31                 NaN
# 166                 Albania          ALB  2021-02-01                 NaN
# ...                     ...          ...         ...                 ...
# 29155                Tuvalu          TUV  2021-05-30                 NaN
# 29156                Tuvalu          TUV  2021-05-31                 NaN
# 29157                Tuvalu          TUV  2021-06-01              2400.0
# 29443  United Arab Emirates          ARE  2021-01-06            826301.0
# 30058               Uruguay          URY  2021-02-28               373.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# ...

# %%
a.loc[a["daily_vaccinations"] < 2,'daily_vaccinations'] = 76

# %%
a[a["daily_vaccinations"] == 76]
# Out:
#                     country country_code        date  total_vaccinations  \
# 162                 Albania          ALB  2021-01-28                 NaN
# 163                 Albania          ALB  2021-01-29                 NaN
# 164                 Albania          ALB  2021-01-30                 NaN
# 165                 Albania          ALB  2021-01-31                 NaN
# 166                 Albania          ALB  2021-02-01                 NaN
# ...                     ...          ...         ...                 ...
# 29155                Tuvalu          TUV  2021-05-30                 NaN
# 29156                Tuvalu          TUV  2021-05-31                 NaN
# 29157                Tuvalu          TUV  2021-06-01              2400.0
# 29443  United Arab Emirates          ARE  2021-01-06            826301.0
# 30058               Uruguay          URY  2021-02-28               373.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# ...

# %%
b =a

# %%
b[b["daily_vaccinations"]<678] = 0
b
# Out:
#            country country_code        date  total_vaccinations  \
# 1      Afghanistan          AFG  2021-02-22                 0.0
# 2      Afghanistan          AFG  2021-02-23                 NaN
# 3      Afghanistan          AFG  2021-02-24                 NaN
# 4      Afghanistan          AFG  2021-02-25                 NaN
# 5      Afghanistan          AFG  2021-02-26                 NaN
# ...            ...          ...         ...                 ...
# 31236     Zimbabwe          ZWE  2021-07-11           1491397.0
# 31237     Zimbabwe          ZWE  2021-07-12           1531868.0
# 31238     Zimbabwe          ZWE  2021-07-13           1575539.0
# 31239     Zimbabwe          ZWE  2021-07-14           1613640.0
# 31240     Zimbabwe          ZWE  2021-07-15           1666862.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1                    0.0                      0.0           227366.073989
# ...

# %%
b[b["daily_vaccinations"]<678]
# Out:
#       country country_code date  total_vaccinations  people_vaccinated  \
# 145         0            0    0                 0.0                0.0
# 146         0            0    0                 0.0                0.0
# 147         0            0    0                 0.0                0.0
# 148         0            0    0                 0.0                0.0
# 149         0            0    0                 0.0                0.0
# ...       ...          ...  ...                 ...                ...
# 31117       0            0    0                 0.0                0.0
# 31118       0            0    0                 0.0                0.0
# 31119       0            0    0                 0.0                0.0
# 31120       0            0    0                 0.0                0.0
# 31121       0            0    0                 0.0                0.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...
