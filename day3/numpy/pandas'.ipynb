# %%
import numpy as np
import pandas as pd

# %%
series=pd.Series(data= [10,23,23,54])

# %%
series
# Out:
# 0    10
# 1    23
# 2    23
# 3    54
# dtype: int64

# %%
data_dict={'apple':3,'banana':5, 'cherry':7}
series=pd.Series(data_dict)

# %%
data_dict
series
# Out:
# apple     3
# banana    5
# cherry    7
# dtype: int64

# %%
d=[10,20,20]
series=pd.Series(d)
series
# Out:
# 0    10
# 1    20
# 2    20
# dtype: int64

# %%
series.sum()
# Out:
# 50

# %% [markdown]
# # filtering values in pandas
# - series[series>=20]

# %%
series[series>=20]
# Out:
# 1    20
# 2    20
# dtype: int64

# %%
series[series < 20]
# Out:
# 0    10
# dtype: int64

# %%
series=pd.Series(d,index=['a','b','c'])
series
# Out:
# a    10
# b    20
# c    20
# dtype: int64

# %%
d_dict={'apple':3,'banana':5,'cherry':7}
pd.Series(d_dict)
# Out:
# apple     3
# banana    5
# cherry    7
# dtype: int64

# %%
series=pd.Series(10,index=['a','b','c'])
series
# Out:
# a    10
# b    10
# c    10
# dtype: int64

# %% [markdown]
# # dataframes

# %%
d={'name':['alice','bob','charlie'],
  'age':[25,30,35],
    'city':['new york', 'los angeles','chicago']}
pd.DataFrame(d)
# Out:
#       name  age         city
# 0    alice   25     new york
# 1      bob   30  los angeles
# 2  charlie   35      chicago

# %%
d=[{'name':'alice','age':25},{'name':'bob','age':32}]

# %%
pd.DataFrame(d)
# Out:
#     name  age
# 0  alice   25
# 1    bob   32

# %%
n=['alice','bob','chalie']
age = [25,30,35]
city=['new york', 'los angeles','chicago']
pd.DataFrame({'name':n,'Age':age,'Cityy':city})
# Out:
#      name  Age        Cityy
# 0   alice   25     new york
# 1     bob   30  los angeles
# 2  chalie   35      chicago

# %%
a=np.array([[25,'new'],[30,'La'],[35,'Ch']])
pd.DataFrame(a,columns=['lane no','City'])
# Out:
#   lane no City
# 0      25  new
# 1      30   La
# 2      35   Ch

# %%
x = pd.read_csv('sqrt.csv')

# %%
x
# Out:
#     # number   sqrt
# 0           1  1.00
# 1           2  1.41
# 2           3  1.73
# 3           4  2.00
# 4           5  2.24
# 5           6  2.45
# 6           7  2.65
# 7           8  2.83
# 8           9  3.00
# 9          10  3.16
# 10         11  3.32
# 11         12  3.46
# 12         13  3.61
# 13         14  3.74
# 14         15  3.87
# 15         16  4.00

# %%
name=pd.Series(['Anand','Priya','Aryan'], name='Name')
ages=pd.Series([25,30,35],name='Age')

pd.concat([name,ages],axis=1)
# Out:
#     Name  Age
# 0  Anand   25
# 1  Priya   30
# 2  Aryan   35

# %%
data={ 'name':['Anand','Adrsh','Aryan'] ,
      'ages':[25,30,35],
'city':['NY','LA','Pune'],
      'marks':[99.7, 78.4, 67.3]}
pd.DataFrame(data)
# Out:
#     name  ages  city  marks
# 0  Anand    25    NY   99.7
# 1  Adrsh    30    LA   78.4
# 2  Aryan    35  Pune   67.3

# %%
x.index = ([x for x in 'abcdefghijklmnop'])

# %% [markdown]
# ### if you want to set some coloum as index thn we can use the __set_index__ method

# %%
print(x)
# Out:
#    # number   sqrt
# a          1  1.00
# b          2  1.41
# c          3  1.73
# d          4  2.00
# e          5  2.24
# f          6  2.45
# g          7  2.65
# h          8  2.83
# i          9  3.00
# j         10  3.16
# k         11  3.32
# l         12  3.46
# m         13  3.61
# n         14  3.74
# o         15  3.87
# p         16  4.00

# %%
x = x.set_index('sqrt')

# %%
x
# Out:
#       # number
# sqrt
# 1.00          1
# 1.41          2
# 1.73          3
# 2.00          4
# 2.24          5
# 2.45          6
# 2.65          7
# 2.83          8
# 3.00          9
# 3.16         10
# 3.32         11
# 3.46         12
# 3.61         13
# 3.74         14
# 3.87         15
# 4.00         16

# %% [markdown]
# ### to change coloumn names
# - __x.columns__

# %%
x = pd.read_csv('sqrt.csv')

# %%
x.columns= ['n00000', 'sqroot']

# %%
x
# Out:
#     n00000  sqroot
# 0        1    1.00
# 1        2    1.41
# 2        3    1.73
# 3        4    2.00
# 4        5    2.24
# 5        6    2.45
# 6        7    2.65
# 7        8    2.83
# 8        9    3.00
# 9       10    3.16
# 10      11    3.32
# 11      12    3.46
# 12      13    3.61
# 13      14    3.74
# 14      15    3.87
# 15      16    4.00

# %% [markdown]
# ### df.rename can also be used for renaming the column name

# %%
x = x.rename(columns={'number':'no.'})

# %%
x
# Out:
#     integers  sqrt
# 0          1  1.00
# 1          2  1.41
# 2          3  1.73
# 3          4  2.00
# 4          5  2.24
# 5          6  2.45
# 6          7  2.65
# 7          8  2.83
# 8          9  3.00
# 9         10  3.16
# 10        11  3.32
# 11        12  3.46
# 12        13  3.61
# 13        14  3.74
# 14        15  3.87
# 15        16  4.00

# %%
x=x.rename(columns={'n00000':'integers', 'sqroot': 'sqrt'})

# %%
x
# Out:
#     integers  sqrt
# 0          1  1.00
# 1          2  1.41
# 2          3  1.73
# 3          4  2.00
# 4          5  2.24
# 5          6  2.45
# 6          7  2.65
# 7          8  2.83
# 8          9  3.00
# 9         10  3.16
# 10        11  3.32
# 11        12  3.46
# 12        13  3.61
# 13        14  3.74
# 14        15  3.87
# 15        16  4.00

# %%
x = x.set_index('sqroot')
x
# Out:
#         integers
# sqroot
# 1.00           1
# 1.41           2
# 1.73           3
# 2.00           4
# 2.24           5
# 2.45           6
# 2.65           7
# 2.83           8
# 3.00           9
# 3.16          10
# 3.32          11
# 3.46          12
# 3.61          13
# 3.74          14
# 3.87          15
# 4.00          16

# %%
x.head()
# Out:
#         integers
# sqroot
# 1.00           1
# 1.41           2
# 1.73           3
# 2.00           4
# 2.24           5

# %%
x.tail()
# Out:
#         integers
# sqroot
# 3.46          12
# 3.61          13
# 3.74          14
# 3.87          15
# 4.00          16

# %%
x.tail(6)
# Out:
#         integers
# sqroot
# 3.32          11
# 3.46          12
# 3.61          13
# 3.74          14
# 3.87          15
# 4.00          16

# %%
df = pd.read_csv('student.csv')

# %%
df.head()
# Out:
#    Roll no     Name  Class  Marks
# 0        1   Aaryan      5     78
# 1        2   Adarsh      6     98
# 2        3    Ankit      7     65
# 3        4     Ashu      8     96
# 4        5  Awasthi      9     78

# %%
df.tail()
# Out:
#    Roll no     Name  Class  Marks
# 3        4     Ashu      8     96
# 4        5  Awasthi      9     78
# 5        6  Krishna     10     64
# 6        7    Priya     11     91
# 7        8     Arti     11     90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  8 non-null      int64
#  1   Name     8 non-null      object
#  2   Class    8 non-null      int64
#  3   Marks    8 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 388.0+ bytes

# %%
df.describe()
# Out:
#        Roll no      Class      Marks
# count  8.00000   8.000000   8.000000
# mean   4.50000   8.375000  82.500000
# std    2.44949   2.263846  13.309503
# min    1.00000   5.000000  64.000000
# 25%    2.75000   6.750000  74.750000
# 50%    4.50000   8.500000  84.000000
# 75%    6.25000  10.250000  92.250000
# max    8.00000  11.000000  98.000000

# %% [markdown]
# ### adding new rows

# %%
# using loc
# the loc
df.loc[8] = [9, 'anu', 8, 83]

# %%
df
# Out:
#    Roll no     Name  Class  Marks
# 0        1   Aaryan      5     78
# 1        2   Adarsh      6     98
# 2        3    Ankit      7     65
# 3        4     Ashu      8     96
# 4        5  Awasthi      9     78
# 5        6  Krishna     10     64
# 6        7    Priya     11     91
# 7        8     Arti     11     90
# 8        9      anu      8     83

# %%
# n_r={'Roll no':10,'Name':'Shanti','Class':np.NaN,'Marks':45}
# df=df.append(n_r)
# append has bdeen discontniud
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16616\815473329.py in ?()
#       1 n_r={'Roll no':10,'Name':'Shanti','Class':np.NaN,'Marks':45}
# ----> 2 df=df.append(n_r)
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
n_r=pd.DataFrame({'Roll no':[10,56],'Name':['Shanti', 'ghgj'],'Class':[np.NaN, 56],'Marks':[45,8]})

# %%
df=pd.concat([df, n_r],  ignore_index=True)

# %%
df
# Out:
#     Roll no     Name  Class  Marks
# 0         1   Aaryan    5.0     78
# 1         2   Adarsh    6.0     98
# 2         3    Ankit    7.0     65
# 3         4     Ashu    8.0     96
# 4         5  Awasthi    9.0     78
# 5         6  Krishna   10.0     64
# 6         7    Priya   11.0     91
# 7         8     Arti   11.0     90
# 8         9      anu    8.0     83
# 9        10   Shanti    NaN     45
# 10       56     ghgj   56.0      8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  11 non-null     int64
#  1   Name     11 non-null     object
#  2   Class    10 non-null     float64
#  3   Marks    11 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 484.0+ bytes

# %%
df.describe()
# Out:
#          Roll no      Class      Marks
# count  11.000000  10.000000  11.000000
# mean   10.090909  13.100000  72.363636
# std    15.494867  15.205628  26.582975
# min     1.000000   5.000000   8.000000
# 25%     3.500000   7.250000  64.500000
# 50%     6.000000   8.500000  78.000000
# 75%     8.500000  10.750000  90.500000
# max    56.000000  56.000000  98.000000

# %% [markdown]
# ## outlier concept

# %%
data = {'Values': [3,4,10,12,12,13,12,14,10,13,13,3200]}
df = pd.DataFrame(data)

# %%
Q1 = df['Values'].quantile(0.25)
Q3 = df['Values'].quantile(0.75)

# %%
Q1
# Out:
# 10.0

# %%
Q3
# Out:
# 13.0

# %%
IQR = Q3 - Q1
lower_bound = Q1- 1.5*IQR
upper_bound = Q3+ 1.5*IQR

outliers=df[(df['Values'] < lower_bound) |(df['Values'] > upper_bound)]
print("Outliers: \n", outliers)
# Out:
# Outliers:
#      Values
# 0        3
# 1        4
# 11    3200

# %%
 Q1- 1.5*IQR
# Out:
# 5.5

# %%
# why multiply by 1.5

# %% [markdown]
# ### data ranking

# %%
data = pd.Series([10,10,20,20,20,30,40], index = ['a','b','c','d','e','f','g'])

# %%
data.rank(method = 'average')
# Out:
# a    1.5
# b    1.5
# c    4.0
# d    4.0
# e    4.0
# f    6.0
# g    7.0
# dtype: float64

# %%
data.rank(method = 'min')
# Out:
# a    1.0
# b    1.0
# c    3.0
# d    3.0
# e    3.0
# f    6.0
# g    7.0
# dtype: float64

# %%
data.rank(method = 'max')
# Out:
# a    2.0
# b    2.0
# c    5.0
# d    5.0
# e    5.0
# f    6.0
# g    7.0
# dtype: float64

# %%
data.rank(method = 'first')
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# f    6.0
# g    7.0
# dtype: float64

# %%
data.rank(method = 'dense')
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    2.0
# f    3.0
# g    4.0
# dtype: float64

# %% [markdown]
# ###  data selection

# %%
d={'name':['alice','bob','charlie' ,'david', 'eve'],
  'age':[25,30,35,67,10000000000000008],
    'city':['new york', 'los angeles','chicago','patna','heaven']}

# %%
df = pd.DataFrame(d, index = ['a','b','c','d','e'])
df
# Out:
#       name                age         city
# a    alice                 25     new york
# b      bob                 30  los angeles
# c  charlie                 35      chicago
# d    david                 67        patna
# e      eve  10000000000000008       heaven

# %%
###Selecting a single Columns

# %%
print(df['name'])
# Out:
# a      alice
# b        bob
# c    charlie
# d      david
# e        eve
# Name: name, dtype: object

# %%
## Selecting multiple colums

# %%
df[['name', 'age']]
# Out:
#       name                age
# a    alice                 25
# b      bob                 30
# c  charlie                 35
# d    david                 67
# e      eve  10000000000000008

# %%
##selecting rows by inex position
df.iloc[0]
# Out:
# name       alice
# age           25
# city    new york
# Name: a, dtype: object

# %%
###selecting rows and columns by labels
df.loc['a':'c', ['name','age']]
# Out:
#       name  age
# a    alice   25
# b      bob   30
# c  charlie   35

# %%
#selecting rows where score is greater than 85
df[df['age']>25]
# Out:
#       name                age         city
# b      bob                 30  los angeles
# c  charlie                 35      chicago
# d    david                 67        patna
# e      eve  10000000000000008       heaven

# %%
#selecting rows where name either 'bob' or 'david'
df[df['name'].isin(['bob','david'])]
# Out:
#     name  age         city
# b    bob   30  los angeles
# d  david   67        patna

# %%
#access scalar values 
# using .at to get the Score of the first row
df.at['a','age']
# Out:
# 25

# %%
df.at['a':'c']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[386], line 1
# ----> 1 df.at['a':'c']
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2575, in _AtIndexer.__getitem__(self, key)
#    2572         raise ValueError("Invalid call for scalar access (getting)!")
#    2573     return self.obj.loc[key]
# -> 2575 return super().__getitem__(key)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2527, in _ScalarAccessIndexer.__getitem__(self, key)
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
#    2526 key = self._convert_key(key)
# -> 2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# TypeError: DataFrame._get_value() missing 1 required positional argument: 'col'

# %%
a = pd.read_csv("student.csv")
a
# Out:
#    Roll no     Name  Class  Marks
# 0        1   Aaryan      5     78
# 1        2   Adarsh      6     98
# 2        3    Ankit      7     65
# 3        4     Ashu      8     96
# 4        5  Awasthi      9     78
# 5        6  Krishna     10     64
# 6        7    Priya     11     91
# 7        8     Arti     11     90

# %%
a.index = [x for x in 'abcdefgh']

# %%
a
# Out:
#    Roll no     Name  Class  Marks
# a        1   Aaryan      5     78
# b        2   Adarsh      6     98
# c        3    Ankit      7     65
# d        4     Ashu      8     96
# e        5  Awasthi      9     78
# f        6  Krishna     10     64
# g        7    Priya     11     91
# h        8     Arti     11     90

# %%
a.head(5)
# Out:
#    Roll no     Name  Class  Marks
# a        1   Aaryan      5     78
# b        2   Adarsh      6     98
# c        3    Ankit      7     65
# d        4     Ashu      8     96
# e        5  Awasthi      9     78

# %%
print(a['Name'].head(3))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[504], line 1
# ----> 1 print(a['Name'].head(3))
#
# ...

# %%
# select where class is 11 and name is arti

# %%
a[a[a['Class'] == 11].isin(['Arti'])]
# Out:
#    Roll no  Name  Class  Marks
# a      NaN   NaN    NaN    NaN
# b      NaN   NaN    NaN    NaN
# c      NaN   NaN    NaN    NaN
# d      NaN   NaN    NaN    NaN
# e      NaN   NaN    NaN    NaN
# f      NaN   NaN    NaN    NaN
# g      NaN   NaN    NaN    NaN
# h      NaN  Arti    NaN    NaN

# %%
b = a[a['Class'] == 11]

# %%
b[b['Name'].isin(['Arti'])]
# Out:
#    Roll no  Name  Class  Marks
# h        8  Arti     11     90

# %%
a[a['Class'] == 11]

# %%
a = pd.read_csv("shopping.csv")

# %%
a.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
a[a['Size'].isin(['L']) & a['Location'].isin(['Maine', 'Oregon'])].head()
# Out:
#      Customer ID  Age Gender Item Purchased     Category  \
# 1              2   19   Male        Sweater     Clothing
# 131          132   28   Male          Skirt     Clothing
# 335          336   20   Male        Sweater     Clothing
# 347          348   36   Male        Sandals     Footwear
# 381          382   66   Male        Jewelry  Accessories
#
#      Purchase Amount (USD) Location Size     Color  Season  Review Rating  \
# 1                       64    Maine    L    Maroon  Winter            3.1
# 131                     29    Maine    L    Indigo  Summer            3.9
# 335                     85   Oregon    L    Maroon  Spring            3.7
# 347                     41   Oregon    L       Red    Fall            3.9
# 381                     25    Maine    L  Lavender  Winter            3.4
#
#     Subscription Status Payment Method Shipping Type Discount Applied  \
# 1                   Yes  Bank Transfer       Express              Yes
# ...

# %%
a['Location'].isin(['Maine', 'Oregon'])
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898    False
# 3899    False
# Name: Location, Length: 3900, dtype: bool

# %%
a['Size'].isin(['L'])
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 3895     True
# 3896     True
# 3897     True
# 3898    False
# 3899    False
# Name: Size, Length: 3900, dtype: bool

# %%
a.iloc[0:5, [0,1,2]]
# Out:
#    Customer ID  Age Gender
# 0            1   55   Male
# 1            2   19   Male
# 2            3   50   Male
# 3            4   21   Male
# 4            5   45   Male

# %%
a.loc[5:10,['Gender', 'Item Purchased','Age']]
# Out:
#    Gender Item Purchased  Age
# 5    Male       Sneakers   46
# 6    Male          Shirt   63
# 7    Male         Shorts   27
# 8    Male           Coat   26
# 9    Male        Handbag   57
# 10   Male          Shoes   53

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
d={'name':['alice','bob','charlie','david','eve'],
  'age':[25,30,35,40,435322],
    'city':['new york', 'los angeles','chicago','ottawa','heaven']}

# %%
a1=pd.DataFrame(d)

# %%
a1['score']=[45,23,63,122,675]

# %%
a1
# Out:
#       name     age         city  Score  score
# 0    alice      25     new york     45     45
# 1      bob      30  los angeles     23     23
# 2  charlie      35      chicago     63     63
# 3    david      40       ottawa    122    122
# 4      eve  435322       heaven    675    675

# %%
a1['score']+=5

# %%
a1
# Out:
#       name     age         city  Score  score
# 0    alice      25     new york     45     50
# 1      bob      30  los angeles     23     28
# 2  charlie      35      chicago     63     68
# 3    david      40       ottawa    122    127
# 4      eve  435322       heaven    675    680

# %%
a1=a1.drop('Score',axis=1)

# %%
a1
# Out:
#       name     age         city  score
# 0    alice      25     new york     50
# 1      bob      30  los angeles     28
# 2  charlie      35      chicago     68
# 3    david      40       ottawa    127
# 4      eve  435322       heaven    680

# %%
a1=a1.sort_values(by='age')
a1
# Out:
#       name     age         city  score
# 0    alice      25     new york     50
# 1      bob      30  los angeles     28
# 2  charlie      35      chicago     68
# 3    david      40       ottawa    127
# 4      eve  435322       heaven    680

# %%
a1=a1.sort_index(ascending=False)
a1
# Out:
#       name     age         city  score
# 4      eve  435322       heaven    680
# 3    david      40       ottawa    127
# 2  charlie      35      chicago     68
# 1      bob      30  los angeles     28
# 0    alice      25     new york     50

# %%
a1.rename(columns={'city':'citi', 'score':'marks'})
# Out:
#       name     age         citi  marks
# 4      eve  435322       heaven    680
# 3    david      40       ottawa    127
# 2  charlie      35      chicago     68
# 1      bob      30  los angeles     28
# 0    alice      25     new york     50

# %%
d={'name':['alice','bob','charlie','david','eve'],
  'age':[25,30,35,40,None],
    'city':['new york', None,'chicago','ottawa',None]}

# %%
a2=pd.DataFrame(d)
a2
# Out:
#       name   age      city
# 0    alice  25.0  new york
# 1      bob  30.0      None
# 2  charlie  35.0   chicago
# 3    david  40.0    ottawa
# 4      eve   NaN      None

# %%
a2['age'].fillna(a2['age'].mean())
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    40.0
# 4    32.5
# Name: age, dtype: float64

# %%
a2['age'].fillna(100000)
# Out:
# 0        25.0
# 1        30.0
# 2        35.0
# 3        40.0
# 4    100000.0
# Name: age, dtype: float64

# %%
a2.dropna()
# Out:
#       name   age      city
# 0    alice  25.0  new york
# 2  charlie  35.0   chicago
# 3    david  40.0    ottawa

# %%
a2['name'].replace({'eve':'adam', 'david':'osama bin laden'})
# Out:
# 0              alice
# 1                bob
# 2            charlie
# 3    osama bin laden
# 4               adam
# 0              kumar
# 1               None
# Name: name, dtype: object

# %%
df = pd.DataFrame({'name' : ['kumar',None], 'age':[78,98],  'city':['patna','darbhanga']})

# %%
a2 = pd.concat([a2, df])

# %%
a2
# Out:
#       name   age       city
# 0    alice  25.0   new york
# 1      bob  30.0       None
# 2  charlie  35.0    chicago
# 3    david  40.0     ottawa
# 4      eve   NaN       None
# 0    kumar  78.0      patna
# 1     None  98.0  darbhanga

# %%
a2['age'].replace(98,'N/A')
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    40.0
# 4     NaN
# 0    78.0
# 1     N/A
# Name: age, dtype: object

# %%
a
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
a = pd.read_csv("country_vaccinations.csv")

# %%
a.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
a["date"] = pd.to_datetime(a['date'], errors = 'coerce')

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31240 entries, 0 to 31239
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              31240 non-null  object
#  1   iso_code                             31240 non-null  object
#  2   date                                 31240 non-null  datetime64[ns]
#  3   total_vaccinations                   17451 non-null  float64
#  4   people_vaccinated                    16554 non-null  float64
#  5   people_fully_vaccinated              13795 non-null  float64
#  6   daily_vaccinations_raw               14421 non-null  float64
#  7   daily_vaccinations                   30948 non-null  float64
#  8   total_vaccinations_per_hundred       17451 non-null  float64
#  9   people_vaccinated_per_hundred        16554 non-null  float64
#  10  people_fully_vaccinated_per_hundred  13795 non-null  float64
# ...

# %%
a.drop_duplicates(inplace = True)
a.head()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
# Q1 = a['sales'].quantile(0.25)
Q1 = a['total_vaccinations'].quantile(0.25)
Q3 = a['total_vaccinations'].quantile(0.75)
IQR = Q3 - Q1
LB = Q1 - 1.5 *IQR
